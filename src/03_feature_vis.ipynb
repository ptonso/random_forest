# %% [markdown]
# # Visualizing my models

# %%
import numpy as np
import pandas as pd

from pkg import utils
from pkg import data_vis

# %%
# Importing featured data

parent = 'data'
filename = 'featured.csv'

path = utils.get_path(parent, filename)
feat_df = pd.read_csv(path, index_col=0)

feat_y = feat_df.iloc[:,0]
feat_X = feat_df.iloc[:,1:]

feat_df.head()
# Out:
#     bayley_3_t1  12DICHLORETHDEG-PWY  AEROBACTINSYN-PWY  ALLANTOINDEG-PWY  \
# 7         100.0                  0.0           0.000000          7.676483
# 8          75.0                  0.0           0.000000         14.984719
# 14         95.0                  0.0         209.593817          0.000000
# 24        115.0                  0.0           0.000000          0.000000
# 26        105.0                  0.0           0.000000          0.000000
#
#     CRNFORCAT-PWY  DENITRIFICATION-PWY  DHGLUCONATE-PYR-CAT-PWY  \
# 7             0.0             0.000000                      0.0
# 8             0.0           320.494755                      0.0
# 14            0.0             0.000000                      0.0
# 24            0.0            26.374059                      0.0
# 26            0.0             0.000000                      0.0
#
#     DTDPRHAMSYN-PWY  METH-ACETATE-PWY    P108-PWY  ...  delivery_mode  \
# ...

# %%
data_vis.pca_2d(feat_X, feat_y)

# %%
data_vis.pca_3d(feat_X, feat_y, multiple_graph=True)

# %%
data_vis.t_sne(feat_X)
