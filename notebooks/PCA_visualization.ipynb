# %% [markdown]
# # Visualizing dataset using PCA dimensional reduction

# %%
# Setup

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d
from sklearn import decomposition

# %%
parent_abs = os.path.abspath(os.path.join(os.getcwd(),os.pardir))
df = pd.read_csv(os.path.join(parent_abs,'data\\featured.csv'),index_col=0)

df.head()
# Out:
#    bayley_3_t1  dominance_simpson  12DICHLORETHDEG-PWY  AEROBACTINSYN-PWY  \
# 0            1           0.136112                  0.0           0.000000
# 1            1           0.451324                  0.0           0.000000
# 2            1           0.281675                  0.0         209.593817
# 3            0           0.945041                  0.0           0.000000
# 4            0           0.338783                  0.0           0.000000
#
#    ALLANTOINDEG-PWY  CRNFORCAT-PWY  DENITRIFICATION-PWY  \
# 0          7.676483            0.0             0.000000
# 1         14.984719            0.0           320.494755
# 2          0.000000            0.0             0.000000
# 3          0.000000            0.0            26.374059
# 4          0.000000            0.0             0.000000
#
#    DHGLUCONATE-PYR-CAT-PWY  DTDPRHAMSYN-PWY  METH-ACETATE-PWY  ...  \
# 0                      0.0      4395.178167               0.0  ...
# 1                      0.0      4478.753445               0.0  ...
# 2                      0.0      2755.525229               0.0  ...
# 3                      0.0      2725.705501               0.0  ...
# 4                      0.0       725.879153               0.0  ...
#
#    delivery_mode  chaos_tot_t1  epds_2c_t1  bisq_3_mins_t1  bisq_4_mins_t1  \
# 0              1           4.0           0           480.0           540.0
# 1              1           1.0           0           570.0           240.0
# 2              1           2.0           0           720.0            90.0
# 3              3           0.0           0           600.0           360.0
# 4              1           7.0           0           420.0           480.0
#
#    bisq_9_mins_t1  bisq_sleep_prob_t1  ebia_tot_t1  educationLevelAhmedNum_t1  \
# 0           239.0                 1.0            0                         16
# 1            60.0                 0.0            0                         20
# 2            30.0                 0.0            0                         16
# 3            30.0                 0.0            2                         16
# 4           120.0                 1.0            0                         12
#
#    a10_t1
# 0       3
# 1       1
# 2       1
# 3       5
# 4       2
#
# [5 rows x 132 columns]

# %%
y = df.iloc[:,0]

# %%
pca = decomposition.PCA(n_components=2)
view = pca.fit_transform(df)
view.shape
# Out:
# (313, 2)

# %%
# 2d Plot (What the fuck does it means?)

plt.scatter(view[:,0], view[:,1],c=y)
plt.xlabel('PCA-1')
plt.ylabel('PCA-2')
# Out:
# Text(0, 0.5, 'PCA-2')

# %%
pca = decomposition.PCA(n_components=3)
view = pca.fit_transform(df)
view.shape


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(221, projection='3d')
alpha = 0.4

ax.scatter(view[:,0], view[:,1], view[:,2],c=y, alpha=alpha)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')


ax = fig.add_subplot(222+i)
ax.scatter(view[:,0], view[:,1],c=y, alpha=alpha)
ax.set_xlabel('y')
ax.set_ylabel('z')

ax = fig.add_subplot(223)
ax.scatter(view[:,0], view[:,2],c=y, alpha=alpha)
ax.set_xlabel('x')
ax.set_ylabel('z')

ax = fig.add_subplot(224)
ax.scatter(view[:,1], view[:,2],c=y, alpha=alpha)
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 16
#      12 ax.set_ylabel('y')
#      13 ax.set_zlabel('z')
# ---> 16 ax = fig.add_subplot(222+i)
#      17 ax.scatter(view[:,0], view[:,1],c=y, alpha=alpha)
#      18 ax.set_xlabel('y')
#
# NameError: name 'i' is not defined
