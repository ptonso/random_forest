# %% [markdown]
# # Visualizing dataset using t-SNE dimensional reduction

# %%
# Setup

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
parent_abs = os.path.abspath(os.path.join(os.getcwd(),os.pardir))
df = pd.read_csv(os.path.join(parent_abs,'data\\featured.csv'),index_col=0)

# %%
df
y = df.iloc[:0]

# %%
plt.figure(figsize=(20,10))
plt.scatter(view[:,0], view[:,1], alpha=0.5)
plt.xlabel('t-SNE-1')
plt.ylabel('t-SNE-2')
# Out:
# Text(0, 0.5, 't-SNE-2')
