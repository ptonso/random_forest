# %% [markdown]
# # Visualizing my models

# %%
import sys
sys.path.append("../")

import os
import numpy as np
import pandas as pd

from src.vis import *

# %%
# Setup df

parent_abs = os.path.abspath(os.path.join(os.getcwd(),os.pardir))
df = pd.read_csv(os.path.join(parent_abs,'data\\featured.csv'),index_col=0)

y = df.iloc[:,0]

# %%
pca_2d(df, y)

# %%
pca_3d(df, y, multiple_graph=True)

# %%
t_sne(df)
